# %% [markdown]
# # Magical Computing
#
# ## What is Quantum Computing?
#
# Quantum computing is a revolutionary approach to computation that harnesses the principles of quantum mechanics, the strange and fascinating theory that governs the behavior of subatomic particles.
#
# ## Qubits: The Building Blocks
#
# In classical computing, information is processed using bits, which can be either 0 or 1. Quantum computing introduces qubits, quantum bits, which can exist in multiple states simultaneously. This property is known as superposition.
#
# ## Superposition: mixture of multiple states
#
# Imagine we have a classical coin that can be either heads (0) or tails (1). In quantum computing, the coin can exist in a superposition of both heads and tails at the same time. This unique feature allows quantum computers to explore multiple possibilities simultaneously.
#
# ## Quantum Gates: The Operations
#
# Classical computers use logic gates to perform operations on bits. Quantum computers use quantum gates to manipulate qubits. Common quantum gates include the Hadamard gate, which creates superposition, and the CNOT gate, which creates entanglement.
#
# ## Entanglement: Magical Connection
#
# Entanglement is another quantum phenomenon where qubits become interconnected and the state of one qubit instantly influences the state of another, regardless of the distance between them. This interdependence enables quantum computers to perform complex computations.
#
# ## Building a Simple Quantum Circuit
#
# we can build basic quantum circuit using Qiskit, a quantum computing framework for Python.

# %%
# Import necessary libraries
from qiskit.visualization import plot_bloch_multivector
from qiskit import QuantumCircuit, Aer, transpile, assemble

# Create a quantum circuit with 1 qubit
qc = QuantumCircuit(1)

# Apply no operation (default state is |0⟩)
# Visualizing the |0⟩ state
qc.draw('mpl')

# %%
# Visualizing the |0⟩ state using a Bloch sphere
state_vector = Aer.get_backend('statevector_simulator')
result = state_vector.run(assemble(qc))
bloch_vector = result.result().get_statevector()

plot_bloch_multivector(bloch_vector)
# Out:
# /tmp/ipykernel_136/2507685538.py:3: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   result = state_vector.run(assemble(qc))

# %%
qc.x(0)
# Visualizing the |1⟩ state using a Bloch sphere
result = state_vector.run(assemble(qc))
bloch_vector = result.result().get_statevector()

plot_bloch_multivector(bloch_vector)
# Out:
# /tmp/ipykernel_136/2875087422.py:5: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   result = state_vector.run(assemble(qc))

# %%
# Import necessary libraries
from qiskit import QuantumCircuit, Aer, transpile, assemble

# Create a quantum circuit with 2 qubits
qc = QuantumCircuit(2, 2)

# Apply a Hadamard gate to the first qubit
qc.h(0)

# Apply a CNOT gate (entanglement) between the qubits
qc.cx(0, 1)

# Measure the qubits
qc.measure([0, 1], [0, 1])

# Visualize the quantum circuit
qc.draw('mpl')
# Out:
# /opt/conda/lib/python3.10/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)
